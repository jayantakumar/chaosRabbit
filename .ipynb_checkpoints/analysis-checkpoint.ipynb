# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("NoPertubationData2",sep="\t")
df
# Out:
#      Unnamed: 0 q_name  q_published  q_publish_rate  q_delivered  \
# 0             0   test     59420886          7864.8     59434965
# 1             1   test     59459577          7738.2     59473953
# 2             2   test     59498830          7850.6     59512983
# 3             3   test     59538445          7923.0     59552547
# 4             4   test     59577830          7877.0     59591913
# ..          ...    ...          ...             ...          ...
# 355         355   test     73328900          7863.8     73350393
# 356         356   test     73368377          7895.4     73389880
# 357         357   test     73407594          7843.4     73429116
# 358         358   test     73486212          7854.0     73468353
# 359         359   test     73525820          7921.6     73507768
#
#      q_delivered_rate  q_messages_count
# 0              7866.0                82
# 1              7797.6                73
# 2              7806.0                87
# ...

# %%
df["q_delivered_rate"].plot(xlabel="Time (s)",ylabel="messages/second")
# Out:
# <Axes: xlabel='Time (s)', ylabel='messages/second'>

# %%
from distfit import distfit
dfit = distfit(distr='popular',bins=50)
dfit.fit_transform(df["q_publish_rate"])
dfit.summary
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.00 sec] [RSS: 5.68449e-06] [loc=7973.623 scale=1928.052]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 6.33291e-06] [loc=0.000 scale=7973.623]
# [distfit] >INFO> [pareto    ] [0.00 sec] [RSS: 6.33291e-06] [loc=-549755813888.000 scale=549755813888.000]
# [distfit] >INFO> [dweibull  ] [0.01 sec] [RSS: 4.52862e-06] [loc=7856.000 scale=1713.170]
# [distfit] >INFO> [t         ] [0.06 sec] [RSS: 5.68445e-06] [loc=7973.579 scale=1927.942]
# [distfit] >INFO> [genextreme] [0.04 sec] [RSS: 6.44347e-06] [loc=0.094 scale=0.288]
# [distfit] >INFO> [gamma     ] [0.03 sec] [RSS: 5.6745e-06] [loc=-21391.481 scale=125.855]
# [distfit] >INFO> [lognorm   ] [0.04 sec] [RSS: 6.46958e-06] [loc=-0.000 scale=0.408]
# [distfit] >INFO> [beta      ] [0.04 sec] [RSS: 5.67249e-06] [loc=-22247.510 scale=1064729260.465]
# [distfit] >INFO> [uniform   ] [0.00 sec] [RSS: 6.23938e-06] [loc=0.000 scale=15791.000]
# ...

# %%
dfit.plot()
# Out:
# [distfit] >INFO> Create pdf plot for the parametric method.
# [distfit] >INFO> Estimated distribution: Dweibull(loc:7856.000000, scale:1713.170354)
# (<Figure size 2000x1500 with 1 Axes>,
#  <Axes: title={'center': '\ndweibull(c=0.360873, loc=7856, scale=1713.17)'}, xlabel='Values', ylabel='Frequency'>)

# %%
df = pd.read_csv("NoPertubationData2",sep="\t")
df["q_messages_count"].quantile(0.2)
# Out:
# 76.0
